# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.applications import VGG16, InceptionV3, ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from drive.MyDrive.DL.codes.transcription.utils import plot_training
import tensorflow as tf
from drive.MyDrive.DL.codes.hatespeech.pipelines import ML,binarize
import warnings
warnings.filterwarnings('ignore')
obj = 'img'
early_stopping = EarlyStopping(monitor='loss', patience=5)

# %%
train = tf.keras.utils.image_dataset_from_directory(f'/content/drive/MyDrive/DL/PREG1/hate-speech/{obj}/train',labels='inferred',label_mode='int',color_mode='rgb',batch_size=32,image_size=(224,224))
valid = tf.keras.utils.image_dataset_from_directory(f'/content/drive/MyDrive/DL/PREG1/hate-speech/{obj}/val',labels='inferred',label_mode='int',color_mode='rgb',batch_size=32,image_size=(224,224))
test  = tf.keras.utils.image_dataset_from_directory(f'/content/drive/MyDrive/DL/PREG1/hate-speech/{obj}/test',labels='inferred',label_mode='int',color_mode='rgb',batch_size=32,image_size=(224,224))

train = train.map(binarize)
valid = valid.map(binarize)
test = test.map(binarize)

resnet_model = ResNet50(include_top=False,input_shape=(224,224,3))
x = Flatten()(resnet_model.output)
x = Dense(128, activation='relu')(x)
output = Dense(1, activation='softmax')(x)

model = Model(inputs=resnet_model.input, outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(
    train,
    validation_data=valid,
    epochs=150,
    callbacks=[early_stopping]
)

model.evaluate(test)
plot_training(history)
# Out:
# Found 71496 files belonging to 6 classes.
# Found 5000 files belonging to 6 classes.
# Found 10000 files belonging to 6 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 1390s 595ms/step - accuracy: 0.3678 - loss: 0.9678 - val_accuracy: 0.4490 - val_loss: 0.7011
# Epoch 2/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 123s 55ms/step - accuracy: 0.3678 - loss: 0.6629 - val_accuracy: 0.4490 - val_loss: 0.6994
# Epoch 3/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 54ms/step - accuracy: 0.3679 - loss: 0.6629 - val_accuracy: 0.4490 - val_loss: 0.7014
# Epoch 4/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3680 - loss: 0.6601 - val_accuracy: 0.4490 - val_loss: 0.7014
# Epoch 5/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3679 - loss: 0.6592 - val_accuracy: 0.4490 - val_loss: 0.7018
# Epoch 6/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3677 - loss: 0.6601 - val_accuracy: 0.4490 - val_loss: 0.7374
# Epoch 7/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 123s 55ms/step - accuracy: 0.3676 - loss: 0.6590 - val_accuracy: 0.4490 - val_loss: 0.7012
# Epoch 8/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 123s 55ms/step - accuracy: 0.3676 - loss: 0.6582 - val_accuracy: 0.4490 - val_loss: 0.7007
# Epoch 9/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 123s 55ms/step - accuracy: 0.3676 - loss: 0.6583 - val_accuracy: 0.4490 - val_loss: 0.7016
# Epoch 10/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 121s 54ms/step - accuracy: 0.3677 - loss: 0.6583 - val_accuracy: 0.4490 - val_loss: 0.7028
# Epoch 11/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3680 - loss: 0.6581 - val_accuracy: 0.4490 - val_loss: 0.7025
# Epoch 12/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3679 - loss: 0.6580 - val_accuracy: 0.4490 - val_loss: 0.7021
# Epoch 13/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3680 - loss: 0.6583 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 14/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3680 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7019
# Epoch 15/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 121s 54ms/step - accuracy: 0.3680 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7040
# Epoch 16/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3680 - loss: 0.6581 - val_accuracy: 0.4490 - val_loss: 0.7015
# Epoch 17/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3679 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7015
# Epoch 18/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3679 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7018
# Epoch 19/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3680 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7018
# Epoch 20/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3679 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 21/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3681 - loss: 0.6580 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 22/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3678 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7016
# Epoch 23/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 54ms/step - accuracy: 0.3677 - loss: 0.6577 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 24/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3678 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 25/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3679 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 26/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 54ms/step - accuracy: 0.3677 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 27/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 55ms/step - accuracy: 0.3676 - loss: 0.6577 - val_accuracy: 0.4490 - val_loss: 0.7018
# Epoch 28/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 121s 54ms/step - accuracy: 0.3681 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 29/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3680 - loss: 0.6579 - val_accuracy: 0.4490 - val_loss: 0.7016
# Epoch 30/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 120s 54ms/step - accuracy: 0.3679 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7017
# Epoch 31/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 122s 54ms/step - accuracy: 0.3678 - loss: 0.6578 - val_accuracy: 0.4490 - val_loss: 0.7018
# Epoch 32/150
# 2235/2235 ━━━━━━━━━━━━━━━━━━━━ 121s 54ms/step - accuracy: 0.3677 - loss: 0.6577 - val_accuracy: 0.4490 - val_loss: 0.7017
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 170s 543ms/step - accuracy: 0.4459 - loss: 0.7000
