# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from drive.MyDrive.DL.codes.hatespeech.pipelines import ML
import warnings
warnings.filterwarnings('ignore')

# %%
ml = ML('txt',yaml_path='/content/drive/MyDrive/DL/PREG1/config.yaml')
ml.training()
ml.test_accuracies()
# Out:
# Found 78886 files belonging to 6 classes.
# Found 5000 files belonging to 6 classes.
# Found 10000 files belonging to 6 classes.
# Training ['tf', 'knn']
# {'tf__max_features': [500, 1000, 5000, 10000], 'tf__max_df': [0.75, 0.85, 1.0], 'tf__use_idf': [True, False], 'knn__n_neighbors': [3, 5, 10, 15, 20]}
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  35.6s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.2s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  36.2s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.7s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.5s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.1s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.6s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.5s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  35.3s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.5s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.7s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.1s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.1s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  36.5s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  36.6s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  35.1s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=  37.2s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.7s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  35.9s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.7s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  36.7s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.6s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.6s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.8s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.7s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  36.1s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.6s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.0s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.9s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.0s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  35.9s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  38.4s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.1s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.9s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.7s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.1s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.5s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  36.1s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  36.8s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.1s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.0s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.7s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=  38.2s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.4s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.1s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.1s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.9s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  38.1s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  35.9s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  36.9s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  38.1s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  36.9s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=  37.4s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.1s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  38.1s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.6s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  35.9s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.9s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.9s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  35.9s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  37.9s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.9s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.9s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=  36.8s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=  37.6s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=  37.8s
# Training ['tf', 'rf']
# {'tf__max_features': [500, 1000, 5000, 10000], 'tf__max_df': [0.75, 0.85, 1.0], 'tf__use_idf': [True, False], 'rf__n_estimators': [50, 100, 200, 500], 'rf__criterion': ['gini', 'entropy'], 'rf__max_depth': ['None', 10, 20, 30, 50, 100], 'rf__min_samples_split': [2, 5, 10], 'rf__min_samples_leaf': [1, 2, 5, 10], 'rf__max_features': ['auto', 'sqrt', 'log2']}
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   1.3s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=False;, score=1.000 total time=   1.3s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   2.8s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.1s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=5000, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=10000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=5000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=auto, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=1000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=1.0, tf__max_features=5000, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=auto, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=10000, tf__use_idf=True;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=auto, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=auto, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=1.0, tf__max_features=1000, tf__use_idf=False;, score=nan total time=   0.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=500, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tf__max_df=0.85, tf__max_features=500, tf__use_idf=False;, score=1.000 total time=   2.7s
# ...
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=7;, score=nan total time=   3.3s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=7;, score=nan total time=   3.5s
# [CV 1/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   3.3s
# [CV 2/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   3.3s
# [CV 3/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   3.5s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.4s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.4s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.5s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   1.8s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   1.6s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   1.8s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.6s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.7s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.8s
# [CV 1/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.0s
# [CV 2/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.0s
# [CV 3/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.0s
# [CV 1/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   3.5s
# [CV 2/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.9s
# [CV 3/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   3.2s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   3.0s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   3.0s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   3.0s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   1.6s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   1.4s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   1.4s
# [CV 1/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   3.1s
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   2.9s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=nan total time=   2.9s
# [CV 1/3] END knn__n_neighbors=15, w2v__min_count=10, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   1.4s
# [CV 2/3] END knn__n_neighbors=15, w2v__min_count=10, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   1.2s
# [CV 3/3] END knn__n_neighbors=15, w2v__min_count=10, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=nan total time=   1.2s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.9s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.7s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.6s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=300, w2v__window=7;, score=nan total time=   1.8s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=300, w2v__window=7;, score=nan total time=   1.6s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=300, w2v__window=7;, score=nan total time=   1.5s
# [CV 1/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.2s
# [CV 2/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.0s
# [CV 3/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=5;, score=nan total time=   3.1s
# [CV 1/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.3s
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.1s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.1s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.5s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.3s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.2s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   8.1s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   7.8s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   7.9s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.2s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.0s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=nan total time=   2.0s
# [CV 1/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   8.1s
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   7.9s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=300, w2v__window=5;, score=nan total time=   7.8s
# [CV 1/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=nan total time=   5.9s
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=nan total time=   5.6s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=1, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=nan total time=   5.7s
# [CV 1/3] END knn__n_neighbors=10, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.4s
# [CV 2/3] END knn__n_neighbors=10, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.6s
# [CV 3/3] END knn__n_neighbors=10, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.4s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.7s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.6s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.5s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   6.6s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   6.8s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=7;, score=nan total time=   6.6s
# [CV 1/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.4s
# [CV 2/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.7s
# [CV 3/3] END knn__n_neighbors=5, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=nan total time=   2.5s
# [CV 1/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   5.8s
# [CV 2/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   6.0s
# [CV 3/3] END knn__n_neighbors=10, w2v__min_count=1, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=nan total time=   5.8s
# [CV 1/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=nan total time=   5.6s
# [CV 2/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=nan total time=   6.0s
# [CV 3/3] END knn__n_neighbors=15, w2v__min_count=1, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=nan total time=   5.9s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=5;, score=nan total time=   1.4s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=5;, score=nan total time=   1.6s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=5;, score=nan total time=   1.4s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.0s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.0s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=1, w2v__sg=0, w2v__vector_size=100, w2v__window=7;, score=nan total time=   3.2s
# [CV 1/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.2s
# [CV 2/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.2s
# [CV 3/3] END knn__n_neighbors=3, w2v__min_count=5, w2v__sg=1, w2v__vector_size=300, w2v__window=3;, score=nan total time=   3.4s
# [CV 1/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.3s
# [CV 2/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.4s
# [CV 3/3] END knn__n_neighbors=20, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=nan total time=   1.5s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-79d5ab081608> in <cell line: 2>()
#       1 ml = ML('txt',yaml_path='/content/drive/MyDrive/DL/PREG1/config.yaml')
# ----> 2 ml.training()
#       3 ml.test_accuracies()
#
# /content/drive/MyDrive/DL/codes/hatespeech/pipelines.py in training(self, log_path)
#     202                 random_state=42
#     203             )
# --> 204             rs.fit(x_train,y_train)
#     205             self.best_models.append(rs.best_estimator_)
#     206
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
#    1021             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1958     def _run_search(self, evaluate_candidates):
#    1959         """Search n_iter candidates from param_distributions"""
# -> 1960         evaluate_candidates(
#    1961             ParameterSampler(
#    1962                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     994                     )
#     995
# --> 996                 _warn_or_raise_about_fit_failures(out, self.error_score)
#     997
#     998                 # For callable self.scoring, the return type is only know after
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     527                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     528             )
# --> 529             raise ValueError(all_fits_failed_message)
#     530
#     531         else:
#
# ValueError:
# All the 150 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 469, in fit
#     Xt = self._fit(X, y, routed_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 406, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/usr/local/lib/python3.10/dist-packages/joblib/memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1310, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 316, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1101, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 316, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/content/drive/MyDrive/DL/codes/hatespeech/pipelines.py", line 93, in transform
#     vectors = [self.w2v_model.wv[word] for word in text if word in self.w2v_model.wv]
#   File "/content/drive/MyDrive/DL/codes/hatespeech/pipelines.py", line 93, in <listcomp>
#     vectors = [self.w2v_model.wv[word] for word in text if word in self.w2v_model.wv]
# AttributeError: 'Word2VecFeatureExtractor' object has no attribute 'w2v_model'
