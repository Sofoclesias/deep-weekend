# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from drive.MyDrive.DL.codes.hatespeech.pipelines import ML
import warnings
warnings.filterwarnings('ignore')

# %%
ml = ML('txt',yaml_path='/content/drive/MyDrive/DL/PREG1/config.yaml')
ml.training()
ml.test_accuracies()
# Out:
# Found 78886 files belonging to 6 classes.
# Found 5000 files belonging to 6 classes.
# Found 10000 files belonging to 6 classes.
# Training ['tf', 'knn']
# {'tf__max_features': [20, 50, 100, 200], 'tf__max_df': [0.75, 0.85], 'tf__use_idf': [True, False], 'knn__n_neighbors': [3, 5, 10, 15, 20]}
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.9s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  36.0s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.4s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.8s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.4s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.3s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.3s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  37.1s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  38.5s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  36.1s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  36.2s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  36.2s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.2s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.9s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.3s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.5s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.5s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.5s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.3s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.0s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.2s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.8s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.1s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  37.6s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.9s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.2s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  38.5s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.5s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.1s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.5s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.6s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.6s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  39.4s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.7s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.9s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  35.7s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  35.7s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.6s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  39.0s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.4s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.4s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.5s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  39.3s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.1s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.8s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  37.7s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.3s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.3s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.7s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  37.4s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.7s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.9s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.4s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  39.3s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  37.6s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.8s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.9s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.6s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  38.8s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  39.6s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.5s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.7s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=  36.7s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  37.9s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.3s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.7s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.9s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  39.6s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  38.0s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.3s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.5s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.2s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  38.5s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=  36.4s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.1s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  37.1s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  38.5s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  36.2s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  36.2s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=  36.3s
# [CV 1/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 2/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.0s
# [CV 3/3] END knn__n_neighbors=5, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  37.2s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.2s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  38.8s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  35.8s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  35.9s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.8s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  39.1s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=  38.7s
# [CV 1/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  36.4s
# [CV 2/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  36.5s
# [CV 3/3] END knn__n_neighbors=3, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=  36.6s
# [CV 1/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  36.1s
# [CV 2/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  37.3s
# [CV 3/3] END knn__n_neighbors=10, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=  38.6s
# [CV 1/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  37.5s
# [CV 2/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  38.8s
# [CV 3/3] END knn__n_neighbors=20, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=  39.0s
# [CV 1/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  37.8s
# [CV 2/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.2s
# [CV 3/3] END knn__n_neighbors=15, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=  39.5s
# Training ['tf', 'rf']
# {'tf__max_features': [20, 50, 100, 200], 'tf__max_df': [0.75, 0.85], 'tf__use_idf': [True, False], 'rf__n_estimators': [50, 100, 200], 'rf__criterion': ['gini', 'entropy'], 'rf__max_depth': [None, 10, 20, 30, 50, 100], 'rf__min_samples_split': [2, 5, 10], 'rf__min_samples_leaf': [1, 2, 5, 10], 'rf__max_features': ['sqrt', 'log2']}
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.1s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.1s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   0.9s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.1s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   0.9s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200, tf__max_df=0.75, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.5s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.75, tf__max_features=100, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=100, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=20, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.1s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=20, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=2, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=50, tf__use_idf=False;, score=1.000 total time=   1.0s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, tf__max_df=0.85, tf__max_features=200, tf__use_idf=False;, score=1.000 total time=   1.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=50, tf__max_df=0.85, tf__max_features=200, tf__use_idf=True;, score=1.000 total time=   1.0s
# ...
# [CV 2/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=1.000 total time=   6.7s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=3;, score=1.000 total time=   6.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   6.6s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   5.7s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   6.2s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.3s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.8s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.3s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.5s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   6.8s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   6.7s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   6.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=5, w2v__sg=1, w2v__vector_size=20, w2v__window=5;, score=1.000 total time=   6.8s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=5, w2v__sg=1, w2v__vector_size=20, w2v__window=5;, score=1.000 total time=   6.8s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=5, w2v__sg=1, w2v__vector_size=20, w2v__window=5;, score=1.000 total time=   6.6s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.9s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.5s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.7s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.1s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.3s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.7s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.7s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=5;, score=1.000 total time=   7.4s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.3s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.5s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=100, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.3s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   6.9s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   7.1s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   7.2s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.1s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.2s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=1, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   7.4s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   6.8s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   6.6s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=1, w2v__vector_size=100, w2v__window=5;, score=1.000 total time=   6.8s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.4s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.6s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.8s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=1, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   7.5s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.9s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.6s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=10, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.8s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   5.2s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   5.7s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=5;, score=1.000 total time=   5.3s
# [CV 1/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   6.2s
# [CV 2/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   6.1s
# [CV 3/3] END rf__criterion=entropy, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=2, rf__n_estimators=100, w2v__min_count=10, w2v__sg=1, w2v__vector_size=20, w2v__window=3;, score=1.000 total time=   6.3s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.0s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.4s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=10, rf__min_samples_split=5, rf__n_estimators=200, w2v__min_count=5, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   6.0s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=1.000 total time=   5.4s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=1.000 total time=   5.3s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=100, w2v__window=3;, score=1.000 total time=   5.7s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.8s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=10, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, w2v__min_count=10, w2v__sg=0, w2v__vector_size=50, w2v__window=3;, score=1.000 total time=   5.7s
# [CV 1/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.6s
# [CV 2/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.5s
# [CV 3/3] END rf__criterion=gini, rf__max_depth=30, rf__max_features=log2, rf__min_samples_leaf=5, rf__min_samples_split=10, rf__n_estimators=50, w2v__min_count=5, w2v__sg=0, w2v__vector_size=200, w2v__window=3;, score=1.000 total time=   5.8s
